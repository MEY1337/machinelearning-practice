# %% [markdown]
# <a href="https://colab.research.google.com/github/MEY1337/machinelearning-practice/blob/main/20242405%EC%9D%B4%EC%9D%B8(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 나의 첫번째 코랩

# %% [markdown]
# 실습 내용
#
# 실습1: Google의 Colab으로 첫번째 파일 생성
#
# 실습2: Git레포지토리 생성
#
# 실습3: Colab 제공 기능으로 github에 업로드하기

# %% [markdown]
# Hello world 출력하기
#
# print 함수 사용

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# 2. Tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
# !pwd
# Out:
# /content
